# %% [markdown]
# <h1><strong>Import library and read dataset</strong></h1>
# <p>Импортируем библиотеку Pandas, присваивая ей сокращение - p.</p>
# <p>Используем read_csv() для чтения нашего датасета.</p>

# %%
import pandas as p

dataset = p.read_csv("sets.csv", encoding="ISO-8859-1")

# %% [markdown]
# <h1><strong>Read dataset</strong></h1>
# <p>Читаем наш датасет (первые 10 строк).</p>

# %%
dataset.head(10)
# Out:
#   Set_ID                    Name  Year      Theme Theme_Group   Subtheme  \
# 0   75-1           PreSchool Set  1975  PreSchool  Pre-school        NaN
# 1   77-1           PreSchool Set  1975  PreSchool  Pre-school        NaN
# 2  077-1          Pre-School Set  1975      Duplo  Pre-school        NaN
# 3   78-1           PreSchool Set  1975  PreSchool  Pre-school        NaN
# 4   78-3               Basic Set  1975  Samsonite     Vintage  Basic set
# 5  133-1              Locomotive  1975     Trains  Modern day    4.5/12V
# 6  134-1  Mobile Crane and Wagon  1975     Trains  Modern day    4.5/12V
# 7  136-1            Tanker Wagon  1975     Trains  Modern day    4.5/12V
# 8  137-2  Passenger Sleeping Car  1975     Trains  Modern day    4.5/12V
# 9  148-1                 Station  1975     Trains  Modern day    4.5/12V
#
#   Category        Packaging  Num_Instructions     Availability  Pieces  \
# 0   Normal  {Not specified}                 0  {Not specified}    16.0
# ...

# %% [markdown]
# <h1><strong></strong></h1>

# %% [markdown]
# <h1><strong>Read dataset</strong></h1>
# <p>Читаем наш датасет (последние 10 строк).</p>

# %%
dataset.tail(10)
# Out:
#          Set_ID                     Name  Year                Theme  \
# 14926  682304-1             Green Goblin  2023  Marvel Super Heroes
# 14927  854234-1     Chili Girl Key Chain  2023                 Gear
# 14928  854236-1    Darth Vader Key Chain  2023                 Gear
# 14929  854240-1       Iron Man Key Chain  2023                 Gear
# 14930  854241-1  Scarlet Witch Key Chain  2023                 Gear
# 14931  854242-1        Creeper Key Chain  2023                 Gear
# 14932  854243-1          Steve Key Chain  2023                 Gear
# 14933  854244-1         Piglin Key Chain  2023                 Gear
# 14934  854245-1   Fennec Shand Key Chain  2023                 Gear
# 14935  854246-1  Scout Trooper Key Chain  2023                 Gear
#
#          Theme_Group                Subtheme Category  Packaging  \
# 14926       Licensed           Magazine Gift    Other  Paper bag
# 14927  Miscellaneous  Key Chains/Minifigures     Gear        Tag
# ...

# %% [markdown]
# <h1><strong>Get dataset information</strong></h1>
# <p>Получаем информацию о нашем датасете.</p>

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 14936 entries, 0 to 14935
# Data columns (total 17 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Set_ID            14936 non-null  object
#  1   Name              14936 non-null  object
#  2   Year              14936 non-null  int64
#  3   Theme             14936 non-null  object
#  4   Theme_Group       14915 non-null  object
#  5   Subtheme          11495 non-null  object
#  6   Category          14936 non-null  object
#  7   Packaging         14936 non-null  object
#  8   Num_Instructions  14936 non-null  int64
#  9   Availability      14936 non-null  object
#  10  Pieces            13133 non-null  float64
#  11  Minifigures       7686 non-null   float64
#  12  Owned             14771 non-null  float64
#  13  Rating            14936 non-null  float64
#  14  USD_MSRP          5837 non-null   float64
#  15  Total_Quantity    12276 non-null  float64
# ...

# %% [markdown]
# <h1><strong>Get dataset columns</strong></h1>
# <p>Список всех колонок.</p>

# %%
dataset.columns
# Out:
# Index(['Set_ID', 'Name', 'Year', 'Theme', 'Theme_Group', 'Subtheme',
#        'Category', 'Packaging', 'Num_Instructions', 'Availability', 'Pieces',
#        'Minifigures', 'Owned', 'Rating', 'USD_MSRP', 'Total_Quantity',
#        'Current_Price'],
#       dtype='object')

# %% [markdown]
# <h1><strong>Format to numpy</strong></h1>
# <p>Форматируем наш датасет в формат numpy.</p>

# %%
dataset.to_numpy()
# Out:
# array([['75-1', 'PreSchool Set', 1975, ..., nan, nan, nan],
#        ['77-1', 'PreSchool Set', 1975, ..., nan, nan, nan],
#        ['077-1', 'Pre-School Set', 1975, ..., nan, 0.0, nan],
#        ...,
#        ['854244-1', 'Piglin Key Chain', 2023, ..., 5.99, nan, nan],
#        ['854245-1', 'Fennec Shand Key Chain', 2023, ..., 5.99, nan, nan],
#        ['854246-1', 'Scout Trooper Key Chain', 2023, ..., 5.99, nan, nan]],
#       dtype=object)

# %% [markdown]
# <h1><strong>Dataset analys</strong></h1>
# <p>Получение статического описание данных..</p>

# %%
dataset.describe()
# Out:
#                Year  Num_Instructions        Pieces  Minifigures  \
# count  14936.000000      14936.000000  13133.000000  7686.000000
# mean    2006.750736          1.196036    237.935734     2.709862
# std       11.524612          2.087763    473.090631     2.955427
# min     1975.000000          0.000000      0.000000     1.000000
# 25%     2000.000000          0.000000     25.000000     1.000000
# 50%     2009.000000          0.000000     81.000000     2.000000
# 75%     2016.000000          2.000000    262.000000     3.000000
# max     2023.000000         48.000000  11695.000000    80.000000
#
#               Owned        Rating     USD_MSRP  Total_Quantity  Current_Price
# count  14771.000000  14936.000000  5837.000000    12276.000000    5442.000000
# mean    2045.236951      1.826627    39.967050        4.708618      90.164663
# std     2972.330218      1.950909    55.006213       20.995961     193.452605
# ...

# %% [markdown]
# <h1><strong></strong></h1>

# %% [markdown]
# <h1><strong>Dataset nunique</strong></h1>
# <p>Подсчет уникальных значений в столбце.</p>

# %%
dataset.nunique()
# Out:
# Set_ID              14936
# Name                12372
# Year                   49
# Theme                 155
# Theme_Group            16
# Subtheme              783
# Category                7
# Packaging              17
# Num_Instructions       27
# Availability           10
# Pieces               1372
# Minifigures            31
# Owned                5340
# Rating                 30
# USD_MSRP              118
# Total_Quantity        154
# Current_Price        2063
# dtype: int64

# %% [markdown]
# <h1><strong>Dataset unique</strong></h1>
# <p>Получаем массив уникальных значений.</p>

# %%
dataset['Category'].unique()
# Out:
# array(['Normal', 'Book', 'Gear', 'Other', 'Collection', 'Extended',
#        'Random'], dtype=object)

# %% [markdown]
# <h1><strong>Delete duplicates from dataset</strong></h1>
# <p>Удаление дубликатов из датасета.</p>

# %%
dataset.drop_duplicates()
# Out:
#          Set_ID                     Name  Year      Theme    Theme_Group  \
# 0          75-1            PreSchool Set  1975  PreSchool     Pre-school
# 1          77-1            PreSchool Set  1975  PreSchool     Pre-school
# 2         077-1           Pre-School Set  1975      Duplo     Pre-school
# 3          78-1            PreSchool Set  1975  PreSchool     Pre-school
# 4          78-3                Basic Set  1975  Samsonite        Vintage
# ...         ...                      ...   ...        ...            ...
# 14931  854242-1        Creeper Key Chain  2023       Gear  Miscellaneous
# 14932  854243-1          Steve Key Chain  2023       Gear  Miscellaneous
# 14933  854244-1         Piglin Key Chain  2023       Gear  Miscellaneous
# 14934  854245-1   Fennec Shand Key Chain  2023       Gear  Miscellaneous
# 14935  854246-1  Scout Trooper Key Chain  2023       Gear  Miscellaneous
#
#                    Subtheme Category        Packaging  Num_Instructions  \
# ...

# %% [markdown]
# <h1><strong>Sort dataset</strong></h1>
# <p>Сортируем значения в датасете используя столбец Rating.</p>

# %%
dataset.sort_values(by="Rating")
# Out:
#         Set_ID                        Name  Year       Theme  \
# 5600   65487-1            Bonus/Value Pack  2004    Bionicle
# 5647  851056-1         Bionicle Carry Case  2004        Gear
# 5646  851044-1                      R2-D2   2004        Gear
# 5645  851039-1              Chef Key Chain  2004        Gear
# 5644  851037-1                Train Worker  2004        Gear
# ...        ...                         ...   ...         ...
# 2763    5561-1              Big Foot 4 x 4  1997  Model Team
# 6753    8924-1          Maxilos and Spinax  2007    Bionicle
# 363      928-1  Space Cruiser And Moonbase  1979       Space
# 3484    5563-1                Racing Truck  1999  Model Team
# 7112    7649-1   MT-201 Ultra-Drill Walker  2008       Space
#
#            Theme_Group               Subtheme    Category           Packaging  \
# 5600      Constraction     Product Collection  Collection     {Not specified}
# ...

# %% [markdown]
# <h1><strong>Dataset column</strong></h1>
# <p>Вывод конкретных данных.</p>

# %%
dataset['Name']
# Out:
# 0                  PreSchool Set
# 1                  PreSchool Set
# 2                 Pre-School Set
# 3                  PreSchool Set
# 4                      Basic Set
#                   ...
# 14931          Creeper Key Chain
# 14932            Steve Key Chain
# 14933           Piglin Key Chain
# 14934     Fennec Shand Key Chain
# 14935    Scout Trooper Key Chain
# Name: Name, Length: 14936, dtype: object

# %% [markdown]
# <h1><strong>Dataset filter</strong></h1>
# <p>Выводим строки, которые соблюдают условие (Rating > 4.8).</p>

# %%
dataset[dataset['Rating'] >= 4.8]
# Out:
#          Set_ID                                     Name  Year          Theme  \
# 363       928-1               Space Cruiser And Moonbase  1979          Space
# 1756     6542-1                    Launch & Load Seaport  1991           Town
# 2763     5561-1                           Big Foot 4 x 4  1997     Model Team
# 3484     5563-1                             Racing Truck  1999     Model Team
# 6541   PS2935-1  LEGO Star Wars II: The Original Trilogy  2006           Gear
# 6753     8924-1                       Maxilos and Spinax  2007       Bionicle
# 7112     7649-1                MT-201 Ultra-Drill Walker  2008          Space
# 7223     8943-1                               Axalara T9  2008       Bionicle
# 9666    45544-1                   Education EV3 Core Set  2013      Education
# 13944   10305-1                     Lion Knights' Castle  2022          Icons
# 13951   10497-1                          Galaxy Explorer  2022          Icons
# ...

# %% [markdown]
# <h1><strong>Dataset analys</strong></h1>
# <p>(Количество строк, количество столбцов)</p>

# %%
dataset.shape
# Out:
# (14936, 17)

# %% [markdown]
# <h1><strong>Delete some column from dataset</strong></h1>
# <p>Удаляем колонку USD_MSRP из датасета.</p>

# %%
dataset.drop(columns=["USD_MSRP"])
# Out:
#          Set_ID                     Name  Year      Theme    Theme_Group  \
# 0          75-1            PreSchool Set  1975  PreSchool     Pre-school
# 1          77-1            PreSchool Set  1975  PreSchool     Pre-school
# 2         077-1           Pre-School Set  1975      Duplo     Pre-school
# 3          78-1            PreSchool Set  1975  PreSchool     Pre-school
# 4          78-3                Basic Set  1975  Samsonite        Vintage
# ...         ...                      ...   ...        ...            ...
# 14931  854242-1        Creeper Key Chain  2023       Gear  Miscellaneous
# 14932  854243-1          Steve Key Chain  2023       Gear  Miscellaneous
# 14933  854244-1         Piglin Key Chain  2023       Gear  Miscellaneous
# 14934  854245-1   Fennec Shand Key Chain  2023       Gear  Miscellaneous
# 14935  854246-1  Scout Trooper Key Chain  2023       Gear  Miscellaneous
#
#                    Subtheme Category        Packaging  Num_Instructions  \
# ...

# %% [markdown]
# <h1><strong>Dataset analys</strong></h1>
# <p>Процентное соотношение пропущенных значений.</p>

# %%
dataset.isnull().mean() * 100
# Out:
# Set_ID               0.000000
# Name                 0.000000
# Year                 0.000000
# Theme                0.000000
# Theme_Group          0.140600
# Subtheme            23.038297
# Category             0.000000
# Packaging            0.000000
# Num_Instructions     0.000000
# Availability         0.000000
# Pieces              12.071505
# Minifigures         48.540439
# Owned                1.104713
# Rating               0.000000
# USD_MSRP            60.919925
# Total_Quantity      17.809320
# Current_Price       63.564542
# dtype: float64

# %% [markdown]
# <h1><strong>Replace data from dataset</strong></h1>
# <p>Заменяем данные в датасете.</p>

# %%
dataset = dataset.replace(1975, 1976)

# %% [markdown]
# <h1><strong>Loc</strong></h1>
# <p>Выбор определенных строк и столбцов.</p>

# %%
dataset.loc[[1, 2],["Name", "Year"]]
# Out:
#              Name  Year
# 1   PreSchool Set  1976
# 2  Pre-School Set  1976

# %% [markdown]
# <h1><strong>To list</strong></h1>
# <p>Форматируем датасет в тип данных list.</p>

# %%
dataset.values.tolist()
# Out:
# [['75-1',
#   'PreSchool Set',
#   1976,
#   'PreSchool',
#   'Pre-school',
#   nan,
#   'Normal',
#   '{Not specified}',
#   0,
#   '{Not specified}',
#   16.0,
#   nan,
#   10.0,
#   0.0,
#   nan,
#   nan,
#   nan],
#  ['77-1',
#   'PreSchool Set',
#   1976,
#   'PreSchool',
#   'Pre-school',
#   nan,
#   'Normal',
#   '{Not specified}',
#   0,
#   '{Not specified}',
#   20.0,
#   nan,
#   11.0,
#   0.0,
#   nan,
#   nan,
#   nan],
#  ['077-1',
#   'Pre-School Set',
#   1976,
#   'Duplo',
#   'Pre-school',
#   nan,
#   'Normal',
#   '{Not specified}',
#   0,
#   '{Not specified}',
#   21.0,
#   nan,
#   10.0,
#   0.0,
#   nan,
#   0.0,
#   nan],
#  ['78-1',
#   'PreSchool Set',
#   1976,
#   'PreSchool',
#   'Pre-school',
#   nan,
#   'Normal',
#   '{Not specified}',
#   0,
#   '{Not specified}',
#   32.0,
#   nan,
#   8.0,
#   0.0,
#   nan,
#   nan,
#   nan],
#  ['78-3',
#   'Basic Set',
#   1976,
#   'Samsonite',
#   'Vintage',
#   'Basic set',
#   'Normal',
#   'Box',
#   0,
# ...

# %% [markdown]
# <h1><strong>To csv</strong></h1>
# <p>Форматируем датасет в csv формат.</p>

# %%
dataset.to_csv("sets_new.csv", index=False)
